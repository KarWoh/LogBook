-- %% [markdown]
-- # [LogBook]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [LogBook]    Script Date: 19/3/2021 4:15:29 PM ******/
CREATE DATABASE [LogBook]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'LogBook', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\LogBook.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'LogBook_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\LogBook_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [LogBook] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [LogBook].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [LogBook] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [LogBook] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [LogBook] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [LogBook] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [LogBook] SET ARITHABORT OFF 
GO
ALTER DATABASE [LogBook] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [LogBook] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [LogBook] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [LogBook] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [LogBook] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [LogBook] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [LogBook] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [LogBook] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [LogBook] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [LogBook] SET  DISABLE_BROKER 
GO
ALTER DATABASE [LogBook] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [LogBook] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [LogBook] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [LogBook] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [LogBook] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [LogBook] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [LogBook] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [LogBook] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [LogBook] SET  MULTI_USER 
GO
ALTER DATABASE [LogBook] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [LogBook] SET DB_CHAINING OFF 
GO
ALTER DATABASE [LogBook] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [LogBook] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [LogBook] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [LogBook] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [LogBook] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [karwohchong]

-- %%
USE [LogBook]
GO

-- %%
/****** Object:  User [karwohchong]    Script Date: 19/3/2021 4:15:29 PM ******/
CREATE USER [karwohchong] FOR LOGIN [karwohchong] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[admin_login_tbl]

-- %%
/****** Object:  Table [dbo].[admin_login_tbl]    Script Date: 19/3/2021 4:15:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[admin_login_tbl](
	[username] [nvarchar](50) NOT NULL,
	[password] [nvarchar](50) NULL,
	[full_name] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[member_login_tbl]

-- %%
/****** Object:  Table [dbo].[member_login_tbl]    Script Date: 19/3/2021 4:15:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[member_login_tbl](
	[full_name] [nvarchar](50) NULL,
	[dob] [nvarchar](50) NULL,
	[contact_no] [nvarchar](50) NULL,
	[email] [nvarchar](50) NULL,
	[state] [nvarchar](50) NULL,
	[city] [nvarchar](50) NULL,
	[postcode] [nvarchar](50) NULL,
	[member_id] [nvarchar](50) NOT NULL,
	[password] [nvarchar](50) NULL,
	[account_status] [nvarchar](50) NULL,
 CONSTRAINT [PK_member_tbl] PRIMARY KEY CLUSTERED 
(
	[member_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[task_detail_tbl]

-- %%
/****** Object:  Table [dbo].[task_detail_tbl]    Script Date: 19/3/2021 4:15:29 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[task_detail_tbl](
	[task_id] [nchar](10) NULL,
	[task_name] [nvarchar](max) NULL,
	[task] [nvarchar](max) NULL,
	[challenges] [nvarchar](max) NULL,
	[overcome] [nvarchar](max) NULL,
	[learning_experience] [nvarchar](max) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [LogBook]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [LogBook] SET  READ_WRITE 
GO
